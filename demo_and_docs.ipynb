# %%
from simplestmaps import (
    draw_map, 
    marker,
    dot,
    label,
    html,
    line,
    area,
    geojson,
)

# %% [markdown]
# # Drawing points
#
# **Markers** are the most basic way of showing a point (coordinates are always lat lon):

# %%
draw_map(
    marker(-20, 30),
    marker(40, -100, popup="hello world!"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83228efa45d59263f11fbf4a2f976922 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83228efa45d59263f11fbf4a2f976922&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83228efa45d59263f11fbf4a2f976922 = L.map(
#                 &quot;map_83228efa45d59263f11fbf4a2f976922&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f26fe70eca81e4c1515ae9ca4d9d2942 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f26fe70eca81e4c1515ae9ca4d9d2942.addTo(map_83228efa45d59263f11fbf4a2f976922);
#
#
#             var marker_f3ce14b49f6a44f591aaf083bc98c723 = L.marker(
#                 [-20.0, 30.0],
#                 {}
#             ).addTo(map_83228efa45d59263f11fbf4a2f976922);
#
#
#             var marker_0d8b10bf073d2a043e709ca0fb83dd08 = L.marker(
#                 [40.0, -100.0],
#                 {}
#             ).addTo(map_83228efa45d59263f11fbf4a2f976922);
#
#
#         var popup_dbb45ad33d54f37b3d3138b9cfe0990d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2043b2d39b8e10febb172c4d121cdbb8 = $(`&lt;div id=&quot;html_2043b2d39b8e10febb172c4d121cdbb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hello world!&lt;/div&gt;`)[0];
#                 popup_dbb45ad33d54f37b3d3138b9cfe0990d.setContent(html_2043b2d39b8e10febb172c4d121cdbb8);
#
#
#
#         marker_0d8b10bf073d2a043e709ca0fb83dd08.bindPopup(popup_dbb45ad33d54f37b3d3138b9cfe0990d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Dots** are a bit more customizable and less intrussive by default (sizes always in pixels):

# %%
draw_map(
    dot(-20, 30),  # by default: small blue dot
    dot(40, -100, popup="hello world!", color="green", radius=10, opacity=0.5, border_color="yellow", border_width=2),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02a7d2c835e35159d3023538c4a38aba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02a7d2c835e35159d3023538c4a38aba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02a7d2c835e35159d3023538c4a38aba = L.map(
#                 &quot;map_02a7d2c835e35159d3023538c4a38aba&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7393830c6242e01b7697111e626972de = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7393830c6242e01b7697111e626972de.addTo(map_02a7d2c835e35159d3023538c4a38aba);
#
#
#             var circle_marker_042b13566f1e5ba2e1ab78b4bbf09012 = L.circleMarker(
#                 [-20.0, 30.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_02a7d2c835e35159d3023538c4a38aba);
#
#
#             var circle_marker_5c0cb84831672f226d10cb7ba989f1a2 = L.circleMarker(
#                 [40.0, -100.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_02a7d2c835e35159d3023538c4a38aba);
#
#
#         var popup_0afe14ec6ea4c3b981ff6e2bb2ae3548 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_999f21502dd86eab906d7b7cd3429fdc = $(`&lt;div id=&quot;html_999f21502dd86eab906d7b7cd3429fdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hello world!&lt;/div&gt;`)[0];
#                 popup_0afe14ec6ea4c3b981ff6e2bb2ae3548.setContent(html_999f21502dd86eab906d7b7cd3429fdc);
#
#
#
#         circle_marker_5c0cb84831672f226d10cb7ba989f1a2.bindPopup(popup_0afe14ec6ea4c3b981ff6e2bb2ae3548)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# You can also draw **text labels** or even **custom html** in the locations of your points:

# %%
draw_map(
    label(-20, 30, text="hello world!"),  # by default: small blue text
    label(30, -75, text="Words", font="Verdana", size=30, color="green", opacity=0.9, popup="this is customizable!"),

    html(10, -40, code='<ul style="color:red"><li><strong>apples</strong></li><li>oranges</li></ul>', popup="custom html markers!"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d88f92271ff8613390d57e4e04a6ec4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d88f92271ff8613390d57e4e04a6ec4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d88f92271ff8613390d57e4e04a6ec4 = L.map(
#                 &quot;map_5d88f92271ff8613390d57e4e04a6ec4&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0def3dc1162d9e3e2cb79e98ef7263ff = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0def3dc1162d9e3e2cb79e98ef7263ff.addTo(map_5d88f92271ff8613390d57e4e04a6ec4);
#
#
#             var marker_dc56ad0ef7a546e4f55b32eae18bac04 = L.marker(
#                 [-20.0, 30.0],
#                 {}
#             ).addTo(map_5d88f92271ff8613390d57e4e04a6ec4);
#
#
#             var div_icon_95af396259502611c41891b05579fa7a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                    \u003cdiv style=\&quot;font-family: arial;\n                                font-size: 12px;\n                                color: blue;\n                                opacity: 1\&quot;\u003e\n                        hello world!\n                    \u003c/div\u003e\n                &quot;});
#             marker_dc56ad0ef7a546e4f55b32eae18bac04.setIcon(div_icon_95af396259502611c41891b05579fa7a);
#
#
#             var marker_2c71b9b00721465121e060c8848e758d = L.marker(
#                 [30.0, -75.0],
#                 {}
#             ).addTo(map_5d88f92271ff8613390d57e4e04a6ec4);
#
#
#             var div_icon_482243ee52c20b4e2f57166e0baf7d4a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                    \u003cdiv style=\&quot;font-family: Verdana;\n                                font-size: 30px;\n                                color: green;\n                                opacity: 0.9\&quot;\u003e\n                        Words\n                    \u003c/div\u003e\n                &quot;});
#             marker_2c71b9b00721465121e060c8848e758d.setIcon(div_icon_482243ee52c20b4e2f57166e0baf7d4a);
#
#
#         var popup_2a34baa36fb9d09462408205eed44101 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e670b7e849a4886ae88517f44d645af = $(`&lt;div id=&quot;html_3e670b7e849a4886ae88517f44d645af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;this is customizable!&lt;/div&gt;`)[0];
#                 popup_2a34baa36fb9d09462408205eed44101.setContent(html_3e670b7e849a4886ae88517f44d645af);
#
#
#
#         marker_2c71b9b00721465121e060c8848e758d.bindPopup(popup_2a34baa36fb9d09462408205eed44101)
#         ;
#
#
#
#
#             var marker_777769db5afe2511b2542f3b06e8d3ce = L.marker(
#                 [10.0, -40.0],
#                 {}
#             ).addTo(map_5d88f92271ff8613390d57e4e04a6ec4);
#
#
#             var div_icon_0ff054c29ea6fb08aefe8281e16379d2 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cul style=\&quot;color:red\&quot;\u003e\u003cli\u003e\u003cstrong\u003eapples\u003c/strong\u003e\u003c/li\u003e\u003cli\u003eoranges\u003c/li\u003e\u003c/ul\u003e&quot;});
#             marker_777769db5afe2511b2542f3b06e8d3ce.setIcon(div_icon_0ff054c29ea6fb08aefe8281e16379d2);
#
#
#         var popup_15cb26db53e43d3754393bbccf2226b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54b179b64e014e30b8edc7a4977bc0c3 = $(`&lt;div id=&quot;html_54b179b64e014e30b8edc7a4977bc0c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;custom html markers!&lt;/div&gt;`)[0];
#                 popup_15cb26db53e43d3754393bbccf2226b8.setContent(html_54b179b64e014e30b8edc7a4977bc0c3);
#
#
#
#         marker_777769db5afe2511b2542f3b06e8d3ce.bindPopup(popup_15cb26db53e43d3754393bbccf2226b8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Lines and Areas
#
# Lines and areas are super easy, they're just sequences of point coordinates and also quite customizable:

# %%
draw_map(
    line([(-35, -65), (5, -70), (40, -100)]),  # by default: thin line
    line([(20, 0), (20, 30), (-20, 30)], color="green", width=10, opacity=0.5, popup="hi!"),

    area([(25, -80), (32, -64), (18, -66)]),  # by default: blue area
    area([(30, 0), (30, 25), (50, 15), (50, 0)], color="green", opacity=0.2, border_color="red", border_width=2, popup="hi!"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84694a4fa1613e1016ecdf73d899f83d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84694a4fa1613e1016ecdf73d899f83d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84694a4fa1613e1016ecdf73d899f83d = L.map(
#                 &quot;map_84694a4fa1613e1016ecdf73d899f83d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21f0d64a2c9c3f8b880e6419850dd065 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_21f0d64a2c9c3f8b880e6419850dd065.addTo(map_84694a4fa1613e1016ecdf73d899f83d);
#
#
#             var poly_line_62b457fdac4ada7c569e5872f25485e4 = L.polyline(
#                 [[-35.0, -65.0], [5.0, -70.0], [40.0, -100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_84694a4fa1613e1016ecdf73d899f83d);
#
#
#             var poly_line_3678a533b5d2c4a8ffda96e12e9a6d7f = L.polyline(
#                 [[20.0, 0.0], [20.0, 30.0], [-20.0, 30.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_84694a4fa1613e1016ecdf73d899f83d);
#
#
#         var popup_bde8c0e99e015c48411c285013bc278c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e3b575a53155ec6893d8c2431eb9614 = $(`&lt;div id=&quot;html_4e3b575a53155ec6893d8c2431eb9614&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hi!&lt;/div&gt;`)[0];
#                 popup_bde8c0e99e015c48411c285013bc278c.setContent(html_4e3b575a53155ec6893d8c2431eb9614);
#
#
#
#         poly_line_3678a533b5d2c4a8ffda96e12e9a6d7f.bindPopup(popup_bde8c0e99e015c48411c285013bc278c)
#         ;
#
#
#
#
#             var polygon_d52b63d1a8ee32e4418685c9e4260460 = L.polygon(
#                 [[25.0, -80.0], [32.0, -64.0], [18.0, -66.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_84694a4fa1613e1016ecdf73d899f83d);
#
#
#             var polygon_09b377fc905feba362a2894db2a3a289 = L.polygon(
#                 [[30.0, 0.0], [30.0, 25.0], [50.0, 15.0], [50.0, 0.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_84694a4fa1613e1016ecdf73d899f83d);
#
#
#         var popup_a617cd56fe3503f5bd8d284d7e80799e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_327e2425ee483702f4cb3c140e075f6b = $(`&lt;div id=&quot;html_327e2425ee483702f4cb3c140e075f6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hi!&lt;/div&gt;`)[0];
#                 popup_a617cd56fe3503f5bd8d284d7e80799e.setContent(html_327e2425ee483702f4cb3c140e075f6b);
#
#
#
#         polygon_09b377fc905feba362a2894db2a3a289.bindPopup(popup_a617cd56fe3503f5bd8d284d7e80799e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Geojson files!
#
# It's super simple to just plot the contents of geojson files.
#
# To customize the elements from the geojson, you can use the same functions used to create normal elements:
#
# - points can be configured to be shown as markers, dots, labels, or htmls
# - lines can be customized with the lines function
# - and areas can be customized with the area function

# %%
draw_map(
    geojson("./readme_example.geojson"),

    geojson("./demo.geojson", 
            points_as=label(text="X", color="green"),
            lines_as=line(color="cyan", width=20, opacity=0.3),
            areas_as=area(color="yellow", border_color="black")),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae58ef61b616c57133966bb5ddcecf08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae58ef61b616c57133966bb5ddcecf08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae58ef61b616c57133966bb5ddcecf08 = L.map(
#                 &quot;map_ae58ef61b616c57133966bb5ddcecf08&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c00e610c7d416aed60842a24e083cd5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5c00e610c7d416aed60842a24e083cd5.addTo(map_ae58ef61b616c57133966bb5ddcecf08);
#
#
#             var marker_3855c5d1b78faa9c6b69449d01d38508 = L.marker(
#                 [-31.266876721234745, -61.49754063958642],
#                 {}
#             ).addTo(map_ae58ef61b616c57133966bb5ddcecf08);
#
#
#             var marker_99b175c97bf08b8c350cd2a852b769b1 = L.marker(
#                 [-31.28080113214235, -61.5057564776007],
#                 {}
#             ).addTo(map_ae58ef61b616c57133966bb5ddcecf08);
#
#
#             var marker_0ceb393283a25489e5f4893eb9a38b47 = L.marker(
#                 [-31.274935068612756, -61.49530790700085],
#                 {}
#             ).addTo(map_ae58ef61b616c57133966bb5ddcecf08);
#
#
#             var marker_d287a7fc6ebf9d43847f414a89f465ca = L.marker(
#                 [-31.252650216241804, -61.49174942173205],
#                 {}
#             ).addTo(map_ae58ef61b616c57133966bb5ddcecf08);
#
#
#             var polygon_863244872f5e28eb07c9185e7e6c54df = L.polygon(
#                 [[-31.27388756140052, -61.510273604158314], [-31.287343249057386, -61.51410096629422], [-31.28979628904363, -61.500270271302114], [-31.276043574213098, -61.497138793191084], [-31.27388756140052, -61.510273604158314]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_ae58ef61b616c57133966bb5ddcecf08);
#
#
#             var poly_line_397776c3d228628e38feec179141e0be = L.polyline(
#                 [[-31.29126457848656, -61.523441142102016], [-31.26752139349587, -61.47841963805594], [-31.25286836171494, -61.491620691758996], [-31.241750751306256, -61.4445303658637]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ae58ef61b616c57133966bb5ddcecf08);
#
#
#             var marker_2a12444bcbe2f7ccfc661de0676e83b4 = L.marker(
#                 [38.09287655309984, -100.58094196533119],
#                 {}
#             ).addTo(map_ae58ef61b616c57133966bb5ddcecf08);
#
#
#             var div_icon_821f52149f0ff53b92e822d7c3402f95 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                    \u003cdiv style=\&quot;font-family: arial;\n                                font-size: 12px;\n                                color: green;\n                                opacity: 1\&quot;\u003e\n                        X\n                    \u003c/div\u003e\n                &quot;});
#             marker_2a12444bcbe2f7ccfc661de0676e83b4.setIcon(div_icon_821f52149f0ff53b92e822d7c3402f95);
#
#
#             var polygon_2f636ad1c152858240c789355bcd05e3 = L.polygon(
#                 [[27.835518539468566, -103.84614574318596], [18.955163888868427, -103.84614574318596], [18.955163888868427, -82.43532147866615], [27.835518539468566, -82.43532147866615], [27.835518539468566, -103.84614574318596]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ae58ef61b616c57133966bb5ddcecf08);

# %% [markdown]
# # Customizing the map view
#
# SimplestMaps uses Folium under the hood, so you can specify a few parameters that are directly translated to the Folium map parameters to customize how it's presented:
#
# (more supported tiles: https://python-visualization.github.io/folium/latest/user_guide/raster_layers/tiles.html )

# %%
draw_map(
    geojson("./readme_example.geojson"),
    center=(-31.27, -61.49), zoom=14, tiles="OpenStreetMap",
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57c5e2e13a8fec6f4ef17c861e4db694 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57c5e2e13a8fec6f4ef17c861e4db694&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57c5e2e13a8fec6f4ef17c861e4db694 = L.map(
#                 &quot;map_57c5e2e13a8fec6f4ef17c861e4db694&quot;,
#                 {
#                     center: [-31.27, -61.49],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14f15fdd05c50e9768952cb99ebc98c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_14f15fdd05c50e9768952cb99ebc98c2.addTo(map_57c5e2e13a8fec6f4ef17c861e4db694);
#
#
#             var marker_9f9f75898c8f22167011c0c031dae6dd = L.marker(
#                 [-31.266876721234745, -61.49754063958642],
#                 {}
#             ).addTo(map_57c5e2e13a8fec6f4ef17c861e4db694);
#
#
#             var marker_86ca9b4ff08d2b970b7dc94f513f65a7 = L.marker(
#                 [-31.28080113214235, -61.5057564776007],
#                 {}
#             ).addTo(map_57c5e2e13a8fec6f4ef17c861e4db694);
#
#
#             var marker_f9d9bcea24c52a11867aef0b6bcf49bb = L.marker(
#                 [-31.274935068612756, -61.49530790700085],
#                 {}
#             ).addTo(map_57c5e2e13a8fec6f4ef17c861e4db694);
#
#
#             var marker_c133dd148f57f108f427722247e2b7a4 = L.marker(
#                 [-31.252650216241804, -61.49174942173205],
#                 {}
#             ).addTo(map_57c5e2e13a8fec6f4ef17c861e4db694);
#
#
#             var polygon_f96b61df5bbf694c1b4b2403668704d2 = L.polygon(
#                 [[-31.27388756140052, -61.510273604158314], [-31.287343249057386, -61.51410096629422], [-31.28979628904363, -61.500270271302114], [-31.276043574213098, -61.497138793191084], [-31.27388756140052, -61.510273604158314]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_57c5e2e13a8fec6f4ef17c861e4db694);
#
#
#             var poly_line_9ef773f3d29e447477cc4ecba006c6a4 = L.polyline(
#                 [[-31.29126457848656, -61.523441142102016], [-31.26752139349587, -61.47841963805594], [-31.25286836171494, -61.491620691758996], [-31.241750751306256, -61.4445303658637]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_57c5e2e13a8fec6f4ef17c861e4db694);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Sets of points, areas or lines
#
# If you have a set of points, lines, areas or geojsons for which you want to use the same style without having to call the helper functions for each element (like in a list comprehension), you can instead use these other helpers. They work just like the single-element versions, except they expect a list of elements as the first argument:

# %%
from simplestmaps import (
    marker_set,
    dot_set,
    label_set,
    html_set,
    line_set,
    area_set,
    geojson_set,
)

draw_map(
    dot_set([(0, -80), (0, 0), (0, 80)], color="green", radius=10),
    line_set([
        [(10, -100), (10, 100)],
        [(-10, -100), (-10, 100)],
    ], color="yellow"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4dca74addc1a442a5f48a602bbd66992 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4dca74addc1a442a5f48a602bbd66992&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4dca74addc1a442a5f48a602bbd66992 = L.map(
#                 &quot;map_4dca74addc1a442a5f48a602bbd66992&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cb97fc020a55ead660389a2c158b01c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9cb97fc020a55ead660389a2c158b01c.addTo(map_4dca74addc1a442a5f48a602bbd66992);
#
#
#             var circle_marker_13ae6f814335471b42bf4d409ee32ea9 = L.circleMarker(
#                 [0.0, 80.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_4dca74addc1a442a5f48a602bbd66992);
#
#
#             var circle_marker_0138fc1291ece0344584fea01b5db7f3 = L.circleMarker(
#                 [0.0, 0.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_4dca74addc1a442a5f48a602bbd66992);
#
#
#             var circle_marker_1bf94b90624682ce216c3a95886eff45 = L.circleMarker(
#                 [0.0, -80.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_4dca74addc1a442a5f48a602bbd66992);
#
#
#             var poly_line_d32df4697cc19a78d39e6bdc6ca52f43 = L.polyline(
#                 [[-10.0, -100.0], [-10.0, 100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_4dca74addc1a442a5f48a602bbd66992);
#
#
#             var poly_line_23c0912fa715749098fd5acfe162b0e1 = L.polyline(
#                 [[10.0, -100.0], [10.0, 100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_4dca74addc1a442a5f48a602bbd66992);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Custom geometry objects instead of (lat,lon) tuples
#
# SimplestMaps supports not only (lat,lon) tuples, but any kind of custom coordinate and geometry containing objects.
#
# If you have a class that represents coordinates and has either:
#
# - "lat" and "lon" attributes
# - "latitude" and "longitude" attributes
# - or "latitude_deg" and "longitude_deg" attributes
#
# Then SimplestMaps already supports them out of the box in all the places where you can use tuples.
#
# For instance:

# %%
class MyCustomPoint:
    def __init__(self, latitude, longitude):
        self.latitude = latitude
        self.longitude = longitude


point_a = MyCustomPoint(-35, -65)
point_b = MyCustomPoint(5, -70)
point_c = MyCustomPoint(40, -100)

draw_map(
    marker(point_a),
    marker(point_b),
    marker(point_c),
    line([point_a, point_b, point_c]),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80e422113dd9df0d37e1580e1f645e6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80e422113dd9df0d37e1580e1f645e6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80e422113dd9df0d37e1580e1f645e6f = L.map(
#                 &quot;map_80e422113dd9df0d37e1580e1f645e6f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_becc190e5803bb4d57353652a01776ff = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_becc190e5803bb4d57353652a01776ff.addTo(map_80e422113dd9df0d37e1580e1f645e6f);
#
#
#             var marker_4691763275cabb969b72b7d91bbd0db0 = L.marker(
#                 [-35.0, -65.0],
#                 {}
#             ).addTo(map_80e422113dd9df0d37e1580e1f645e6f);
#
#
#             var marker_1c682cdee34c091b0f53709f3db7def7 = L.marker(
#                 [5.0, -70.0],
#                 {}
#             ).addTo(map_80e422113dd9df0d37e1580e1f645e6f);
#
#
#             var marker_d254953a2262682d7360a995f281e77e = L.marker(
#                 [40.0, -100.0],
#                 {}
#             ).addTo(map_80e422113dd9df0d37e1580e1f645e6f);
#
#
#             var poly_line_54899e83d05a6a650d9b79c6edf504b2 = L.polyline(
#                 [[-35.0, -65.0], [5.0, -70.0], [40.0, -100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_80e422113dd9df0d37e1580e1f645e6f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# If your custom geometry objects don't follow those attribute naming conventions or represent more complex types like areas or lines, you can simply extract (lat,lon) tuples and use them as inputs for SimplestMaps. But that's tedious if you are doing lots of maps with your custom types.
#
# If that the case, you can tell SimplestMaps how to convert them to avoid having to manually do it each time you need to draw a map. You only need to write a function that is able to receive an instance of your custom type, and return either a single tuple of (lat,lon) coordinates, or a sequence of tuples of (lat,lon) coordinates.
#
# Like this:
#
# (notice how the converter function used for MyCustomArea can just return a list of MyCustomPoint, because we also registered a converter for MyCustomPoint. SimplestMaps tries to save you work as much as it can :) )

# %%
from simplestmaps import auto_convert

class MyCustomPoint:
    def __init__(self, my_latitude, my_longitude):
        self.my_latitude = my_latitude
        self.my_longitude = my_longitude
        
class MyCustomArea:
    def __init__(self, my_coordinates_list):
        self.my_coordinates_list = my_coordinates_list


auto_convert(MyCustomPoint, lambda p: (p.my_latitude, p.my_longitude))
auto_convert(MyCustomArea, lambda a: a.my_coordinates_list)

point_a = MyCustomPoint(-35, -65)
point_b = MyCustomPoint(5, -70)
point_c = MyCustomPoint(40, -100)
area_x = MyCustomArea([point_a, point_b, point_c])

draw_map(
    marker(point_a),
    marker(point_b),
    marker(point_c),
    area(area_x),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdb39caf6d4e4c3523b19dd12f357d7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdb39caf6d4e4c3523b19dd12f357d7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdb39caf6d4e4c3523b19dd12f357d7c = L.map(
#                 &quot;map_fdb39caf6d4e4c3523b19dd12f357d7c&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb05a9fa509b4fadb24b4ce70965585d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb05a9fa509b4fadb24b4ce70965585d.addTo(map_fdb39caf6d4e4c3523b19dd12f357d7c);
#
#
#             var marker_e7d0ad6ce20479a24f1b5a258afec4ee = L.marker(
#                 [-35.0, -65.0],
#                 {}
#             ).addTo(map_fdb39caf6d4e4c3523b19dd12f357d7c);
#
#
#             var marker_62c54664c0904f26bff6fc0b863863c5 = L.marker(
#                 [5.0, -70.0],
#                 {}
#             ).addTo(map_fdb39caf6d4e4c3523b19dd12f357d7c);
#
#
#             var marker_50d243e221dc29b727d2b7f45cb644eb = L.marker(
#                 [40.0, -100.0],
#                 {}
#             ).addTo(map_fdb39caf6d4e4c3523b19dd12f357d7c);
#
#
#             var polygon_7f46544b285eab219b8c1139d86b273e = L.polygon(
#                 [[-35.0, -65.0], [5.0, -70.0], [40.0, -100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_fdb39caf6d4e4c3523b19dd12f357d7c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Integration with Shapely
#
# I'm also working to support shapely polygons and other types of objects! Stay tunned, it's one of my biggest priorities :)
