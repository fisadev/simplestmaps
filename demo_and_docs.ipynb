# %% [markdown]
# # Installation
#
# You can install SimplestMaps with pip:
#
# `pip3 install simplestmaps`
#
# (requires python3)
#
# # Usage
#
# First you need to import some basic utilities that SimplestMaps provides:

# %%
from simplestmaps import (
    draw_map, 
    marker,
    dot,
    label,
    html,
    line,
    area,
    geojson,
)

# %% [markdown]
# And then you can use those utilities to plot all kinds of objects:
#
# # Drawing points
#
# **Markers** are the most basic way of showing a point (coordinates are always lat lon):

# %%
draw_map(
    marker(-20, 30),
    marker(40, -100, popup="hello world!"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50fd12f8f66c8dd7a9cb89dd48df3cb3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50fd12f8f66c8dd7a9cb89dd48df3cb3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50fd12f8f66c8dd7a9cb89dd48df3cb3 = L.map(
#                 &quot;map_50fd12f8f66c8dd7a9cb89dd48df3cb3&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e4ac7cb4877d35f1aa699889973d304 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5e4ac7cb4877d35f1aa699889973d304.addTo(map_50fd12f8f66c8dd7a9cb89dd48df3cb3);
#
#
#             var marker_caca5c432bd4b7cfe7c6ce51c640be3d = L.marker(
#                 [-20.0, 30.0],
#                 {}
#             ).addTo(map_50fd12f8f66c8dd7a9cb89dd48df3cb3);
#
#
#             var marker_9359d106ed9fb4261f55cfe61bfe6386 = L.marker(
#                 [40.0, -100.0],
#                 {}
#             ).addTo(map_50fd12f8f66c8dd7a9cb89dd48df3cb3);
#
#
#         var popup_31754500a80c8bdc69a6ad36139cfe0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0244542a894a158f9498c22b0d3ffb6b = $(`&lt;div id=&quot;html_0244542a894a158f9498c22b0d3ffb6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hello world!&lt;/div&gt;`)[0];
#                 popup_31754500a80c8bdc69a6ad36139cfe0e.setContent(html_0244542a894a158f9498c22b0d3ffb6b);
#
#
#
#         marker_9359d106ed9fb4261f55cfe61bfe6386.bindPopup(popup_31754500a80c8bdc69a6ad36139cfe0e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Dots** are a bit more customizable and less intrussive by default (sizes always in pixels):

# %%
draw_map(
    dot(-20, 30),  # by default: small blue dot
    dot(40, -100, popup="hello world!", color="green", radius=10, opacity=0.5, border_color="yellow", border_width=2),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_106cc32ac7d53fe42e815c36f219f51e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_106cc32ac7d53fe42e815c36f219f51e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_106cc32ac7d53fe42e815c36f219f51e = L.map(
#                 &quot;map_106cc32ac7d53fe42e815c36f219f51e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_628b6f6f43e9e6492ecfb7a5b330a793 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_628b6f6f43e9e6492ecfb7a5b330a793.addTo(map_106cc32ac7d53fe42e815c36f219f51e);
#
#
#             var circle_marker_bcfc8f269aabba42756ff6535c3797a0 = L.circleMarker(
#                 [-20.0, 30.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_106cc32ac7d53fe42e815c36f219f51e);
#
#
#             var circle_marker_0d4773d8ca1902700a37e9d46efce762 = L.circleMarker(
#                 [40.0, -100.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_106cc32ac7d53fe42e815c36f219f51e);
#
#
#         var popup_d9218c46d7a2e7465d0c802c1c465690 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0049991fd2b1fbf8d72012d1f64a0acb = $(`&lt;div id=&quot;html_0049991fd2b1fbf8d72012d1f64a0acb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hello world!&lt;/div&gt;`)[0];
#                 popup_d9218c46d7a2e7465d0c802c1c465690.setContent(html_0049991fd2b1fbf8d72012d1f64a0acb);
#
#
#
#         circle_marker_0d4773d8ca1902700a37e9d46efce762.bindPopup(popup_d9218c46d7a2e7465d0c802c1c465690)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# You can also draw **text labels** or even **custom html** in the locations of your points:

# %%
draw_map(
    label(-20, 30, text="hello world!"),  # by default: small blue text
    label(30, -75, text="Words", font="Verdana", size=30, color="green", opacity=0.9, popup="this is customizable!"),

    html(10, -40, code='<ul style="color:red"><li><strong>apples</strong></li><li>oranges</li></ul>', popup="custom html markers!"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6681ef6be739fb4d0cbe2acc98abcfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6681ef6be739fb4d0cbe2acc98abcfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6681ef6be739fb4d0cbe2acc98abcfc = L.map(
#                 &quot;map_b6681ef6be739fb4d0cbe2acc98abcfc&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a849da7a005b12d2f344aa8db7711784 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a849da7a005b12d2f344aa8db7711784.addTo(map_b6681ef6be739fb4d0cbe2acc98abcfc);
#
#
#             var marker_b2b806c9705112753d7348669f5a4148 = L.marker(
#                 [-20.0, 30.0],
#                 {}
#             ).addTo(map_b6681ef6be739fb4d0cbe2acc98abcfc);
#
#
#             var div_icon_1427d3e89637a06dc2894378eb3e6c47 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                    \u003cdiv style=\&quot;font-family: arial;\n                                font-size: 12px;\n                                color: blue;\n                                opacity: 1\&quot;\u003e\n                        hello world!\n                    \u003c/div\u003e\n                &quot;});
#             marker_b2b806c9705112753d7348669f5a4148.setIcon(div_icon_1427d3e89637a06dc2894378eb3e6c47);
#
#
#             var marker_859c7135974999ce0cf75f6d85ff8a81 = L.marker(
#                 [30.0, -75.0],
#                 {}
#             ).addTo(map_b6681ef6be739fb4d0cbe2acc98abcfc);
#
#
#             var div_icon_217508d6422cff9785f939bb50fc4acf = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                    \u003cdiv style=\&quot;font-family: Verdana;\n                                font-size: 30px;\n                                color: green;\n                                opacity: 0.9\&quot;\u003e\n                        Words\n                    \u003c/div\u003e\n                &quot;});
#             marker_859c7135974999ce0cf75f6d85ff8a81.setIcon(div_icon_217508d6422cff9785f939bb50fc4acf);
#
#
#         var popup_a430b1d41dbd0ae25ae170129862c25b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9574356f31880e2607a9bb13a2c0102e = $(`&lt;div id=&quot;html_9574356f31880e2607a9bb13a2c0102e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;this is customizable!&lt;/div&gt;`)[0];
#                 popup_a430b1d41dbd0ae25ae170129862c25b.setContent(html_9574356f31880e2607a9bb13a2c0102e);
#
#
#
#         marker_859c7135974999ce0cf75f6d85ff8a81.bindPopup(popup_a430b1d41dbd0ae25ae170129862c25b)
#         ;
#
#
#
#
#             var marker_389bc9e20f4dbf49cf1083016c5e6f6b = L.marker(
#                 [10.0, -40.0],
#                 {}
#             ).addTo(map_b6681ef6be739fb4d0cbe2acc98abcfc);
#
#
#             var div_icon_208a15d4ad3a939e7ad92693de002eee = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cul style=\&quot;color:red\&quot;\u003e\u003cli\u003e\u003cstrong\u003eapples\u003c/strong\u003e\u003c/li\u003e\u003cli\u003eoranges\u003c/li\u003e\u003c/ul\u003e&quot;});
#             marker_389bc9e20f4dbf49cf1083016c5e6f6b.setIcon(div_icon_208a15d4ad3a939e7ad92693de002eee);
#
#
#         var popup_4f22793935834da549367b8a548ad79e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_358075573d21b46fafcafeb951b4e463 = $(`&lt;div id=&quot;html_358075573d21b46fafcafeb951b4e463&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;custom html markers!&lt;/div&gt;`)[0];
#                 popup_4f22793935834da549367b8a548ad79e.setContent(html_358075573d21b46fafcafeb951b4e463);
#
#
#
#         marker_389bc9e20f4dbf49cf1083016c5e6f6b.bindPopup(popup_4f22793935834da549367b8a548ad79e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Lines and Areas
#
# Lines and areas are super easy, they're just sequences of point coordinates and also quite customizable:

# %%
draw_map(
    line([(-35, -65), (5, -70), (40, -100)]),  # by default: thin line
    line([(20, 0), (20, 30), (-20, 30)], color="green", width=10, opacity=0.5, popup="hi!"),

    area([(25, -80), (32, -64), (18, -66)]),  # by default: blue area
    area([(30, 0), (30, 25), (50, 15), (50, 0)], color="green", opacity=0.2, border_color="red", border_width=2, popup="hi!"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e5a44c177fcdcb772cbf5503808fac1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e5a44c177fcdcb772cbf5503808fac1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e5a44c177fcdcb772cbf5503808fac1 = L.map(
#                 &quot;map_2e5a44c177fcdcb772cbf5503808fac1&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b7e0c16643901345e3878f439668502 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7b7e0c16643901345e3878f439668502.addTo(map_2e5a44c177fcdcb772cbf5503808fac1);
#
#
#             var poly_line_96e38366b8be5c00af6094704080e1fb = L.polyline(
#                 [[-35.0, -65.0], [5.0, -70.0], [40.0, -100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_2e5a44c177fcdcb772cbf5503808fac1);
#
#
#             var poly_line_8dff89b73975727996a3b4a0ed01e8f3 = L.polyline(
#                 [[20.0, 0.0], [20.0, 30.0], [-20.0, 30.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_2e5a44c177fcdcb772cbf5503808fac1);
#
#
#         var popup_9d76daa9e6bd5aff6462ebba1ebe8c66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd66219add9e5839f9d5985f18053176 = $(`&lt;div id=&quot;html_fd66219add9e5839f9d5985f18053176&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hi!&lt;/div&gt;`)[0];
#                 popup_9d76daa9e6bd5aff6462ebba1ebe8c66.setContent(html_fd66219add9e5839f9d5985f18053176);
#
#
#
#         poly_line_8dff89b73975727996a3b4a0ed01e8f3.bindPopup(popup_9d76daa9e6bd5aff6462ebba1ebe8c66)
#         ;
#
#
#
#
#             var polygon_e411d33cb6fb5cb1c9bc7af658736981 = L.polygon(
#                 [[25.0, -80.0], [32.0, -64.0], [18.0, -66.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_2e5a44c177fcdcb772cbf5503808fac1);
#
#
#             var polygon_737cd1857711523589037bc7b50c8c2a = L.polygon(
#                 [[30.0, 0.0], [30.0, 25.0], [50.0, 15.0], [50.0, 0.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_2e5a44c177fcdcb772cbf5503808fac1);
#
#
#         var popup_f047eb6c41ff9f2f63ad7254b412310c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a31e5cd21f4ab7338a0f7384577fbc5 = $(`&lt;div id=&quot;html_6a31e5cd21f4ab7338a0f7384577fbc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hi!&lt;/div&gt;`)[0];
#                 popup_f047eb6c41ff9f2f63ad7254b412310c.setContent(html_6a31e5cd21f4ab7338a0f7384577fbc5);
#
#
#
#         polygon_737cd1857711523589037bc7b50c8c2a.bindPopup(popup_f047eb6c41ff9f2f63ad7254b412310c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Geojson files!
#
# It's super simple to just plot the contents of geojson files.
#
# To customize the elements from the geojson, you can use the same functions used to create normal elements:
#
# - points can be configured to be shown as markers, dots, labels, or htmls
# - lines can be customized with the lines function
# - and areas can be customized with the area function

# %%
draw_map(
    geojson("./readme_example.geojson"),

    geojson("./demo.geojson", 
            points_as=label(text="X", color="green"),
            lines_as=line(color="cyan", width=20, opacity=0.3),
            areas_as=area(color="yellow", border_color="black")),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72868861c4f2aa56490acdd4ec6bcc1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72868861c4f2aa56490acdd4ec6bcc1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72868861c4f2aa56490acdd4ec6bcc1b = L.map(
#                 &quot;map_72868861c4f2aa56490acdd4ec6bcc1b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d207bca20571c6c289c90d9e0c86e7c5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d207bca20571c6c289c90d9e0c86e7c5.addTo(map_72868861c4f2aa56490acdd4ec6bcc1b);
#
#
#             var marker_d0e794eff8d889b5dfbfe9a1ed494cc4 = L.marker(
#                 [-31.266876721234745, -61.49754063958642],
#                 {}
#             ).addTo(map_72868861c4f2aa56490acdd4ec6bcc1b);
#
#
#             var marker_d642b94c72bd12085620a3cc91565f13 = L.marker(
#                 [-31.28080113214235, -61.5057564776007],
#                 {}
#             ).addTo(map_72868861c4f2aa56490acdd4ec6bcc1b);
#
#
#             var marker_64791ef131cee14fbd0585bfb0e7c3ac = L.marker(
#                 [-31.274935068612756, -61.49530790700085],
#                 {}
#             ).addTo(map_72868861c4f2aa56490acdd4ec6bcc1b);
#
#
#             var marker_b448d0ed73089b3468176e8b709e81b0 = L.marker(
#                 [-31.252650216241804, -61.49174942173205],
#                 {}
#             ).addTo(map_72868861c4f2aa56490acdd4ec6bcc1b);
#
#
#             var polygon_2775a9ccfdcdde680441692621762fde = L.polygon(
#                 [[-31.27388756140052, -61.510273604158314], [-31.287343249057386, -61.51410096629422], [-31.28979628904363, -61.500270271302114], [-31.276043574213098, -61.497138793191084], [-31.27388756140052, -61.510273604158314]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_72868861c4f2aa56490acdd4ec6bcc1b);
#
#
#             var poly_line_892af793f5cbb4895b31f2662e498ff1 = L.polyline(
#                 [[-31.29126457848656, -61.523441142102016], [-31.26752139349587, -61.47841963805594], [-31.25286836171494, -61.491620691758996], [-31.241750751306256, -61.4445303658637]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_72868861c4f2aa56490acdd4ec6bcc1b);
#
#
#             var marker_d4dac56c49fff05fbb93d7dc7d40944d = L.marker(
#                 [38.09287655309984, -100.58094196533119],
#                 {}
#             ).addTo(map_72868861c4f2aa56490acdd4ec6bcc1b);
#
#
#             var div_icon_60a25216cd8329e8700928a8b983f30a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                    \u003cdiv style=\&quot;font-family: arial;\n                                font-size: 12px;\n                                color: green;\n                                opacity: 1\&quot;\u003e\n                        X\n                    \u003c/div\u003e\n                &quot;});
#             marker_d4dac56c49fff05fbb93d7dc7d40944d.setIcon(div_icon_60a25216cd8329e8700928a8b983f30a);
#
#
#             var polygon_821b6c6daac7bb7d1229b503707ec088 = L.polygon(
#                 [[27.835518539468566, -103.84614574318596], [18.955163888868427, -103.84614574318596], [18.955163888868427, -82.43532147866615], [27.835518539468566, -82.43532147866615], [27.835518539468566, -103.84614574318596]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_72868861c4f2aa56490acdd4ec6bcc1b);

# %% [markdown]
# # Customizing the map view
#
# SimplestMaps uses Folium under the hood, so you can specify a few parameters that are directly translated to the Folium map parameters to customize how it's presented. Right now, you can set the coordinates of the map center, its zoom level, and the tiles to display.
#
# (more supported tiles: https://python-visualization.github.io/folium/latest/user_guide/raster_layers/tiles.html )

# %%
draw_map(
    geojson("./readme_example.geojson"),
    center=(-31.27, -61.49), zoom=14, tiles="OpenStreetMap",
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a879b310da4d7641e73123fd8b1eca2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a879b310da4d7641e73123fd8b1eca2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a879b310da4d7641e73123fd8b1eca2b = L.map(
#                 &quot;map_a879b310da4d7641e73123fd8b1eca2b&quot;,
#                 {
#                     center: [-31.27, -61.49],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_029ed790b0f18c8ecfacf9ae481c228c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_029ed790b0f18c8ecfacf9ae481c228c.addTo(map_a879b310da4d7641e73123fd8b1eca2b);
#
#
#             var marker_e6bf30ad23465e36d759c115e2fbe19a = L.marker(
#                 [-31.266876721234745, -61.49754063958642],
#                 {}
#             ).addTo(map_a879b310da4d7641e73123fd8b1eca2b);
#
#
#             var marker_87f05efe831b6cfc19e4450afedb43bb = L.marker(
#                 [-31.28080113214235, -61.5057564776007],
#                 {}
#             ).addTo(map_a879b310da4d7641e73123fd8b1eca2b);
#
#
#             var marker_9a3fc77a390bf13232c8c5475f35b740 = L.marker(
#                 [-31.274935068612756, -61.49530790700085],
#                 {}
#             ).addTo(map_a879b310da4d7641e73123fd8b1eca2b);
#
#
#             var marker_6d9448944d30c5861e331a49dc5ec38e = L.marker(
#                 [-31.252650216241804, -61.49174942173205],
#                 {}
#             ).addTo(map_a879b310da4d7641e73123fd8b1eca2b);
#
#
#             var polygon_d91785cfba24cc94c7db5653b01bdfd3 = L.polygon(
#                 [[-31.27388756140052, -61.510273604158314], [-31.287343249057386, -61.51410096629422], [-31.28979628904363, -61.500270271302114], [-31.276043574213098, -61.497138793191084], [-31.27388756140052, -61.510273604158314]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_a879b310da4d7641e73123fd8b1eca2b);
#
#
#             var poly_line_da866de9ba83bf8ebc275e4208199839 = L.polyline(
#                 [[-31.29126457848656, -61.523441142102016], [-31.26752139349587, -61.47841963805594], [-31.25286836171494, -61.491620691758996], [-31.241750751306256, -61.4445303658637]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_a879b310da4d7641e73123fd8b1eca2b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Sets of points, areas or lines
#
# If you have a set of points, lines, areas or geojsons for which you want to use the same style without having to call the helper functions for each element (like in a list comprehension), you can instead use these other helpers. They work just like the single-element versions, except they expect a list of elements as the first argument:

# %%
from simplestmaps import (
    marker_set,
    dot_set,
    label_set,
    html_set,
    line_set,
    area_set,
    geojson_set,
)

draw_map(
    dot_set([(0, -80), (0, 0), (0, 80)], color="green", radius=10),
    line_set([
        [(10, -100), (10, 100)],
        [(-10, -100), (-10, 100)],
    ], color="yellow"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26290b78b8e6e4589d2c7a5815401369 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26290b78b8e6e4589d2c7a5815401369&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26290b78b8e6e4589d2c7a5815401369 = L.map(
#                 &quot;map_26290b78b8e6e4589d2c7a5815401369&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58e63815a0ee59369e84fbb1e96aa81d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_58e63815a0ee59369e84fbb1e96aa81d.addTo(map_26290b78b8e6e4589d2c7a5815401369);
#
#
#             var circle_marker_88aad72440737e9252a9ad6a87fc1a4e = L.circleMarker(
#                 [0.0, 80.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_26290b78b8e6e4589d2c7a5815401369);
#
#
#             var circle_marker_e611911c335276bafe2ec5b3ab6c4a0c = L.circleMarker(
#                 [0.0, 0.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_26290b78b8e6e4589d2c7a5815401369);
#
#
#             var circle_marker_cd27c6e551e0820add96968c3a462dfe = L.circleMarker(
#                 [0.0, -80.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_26290b78b8e6e4589d2c7a5815401369);
#
#
#             var poly_line_2104f3a74eb12b27fa9cbba9098d31e1 = L.polyline(
#                 [[-10.0, -100.0], [-10.0, 100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_26290b78b8e6e4589d2c7a5815401369);
#
#
#             var poly_line_ceab64dbec0307a0580e5355f5f20e39 = L.polyline(
#                 [[10.0, -100.0], [10.0, 100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_26290b78b8e6e4589d2c7a5815401369);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Integration with Shapely
#
# 📣 New in v1.3.0! 📣
#
# Shapely is supported out of the box too! You can use its geometries instead of coordinates tuples.
#
# Remember to use the "_set" helpers (dot_set, area_set, etc) for shapely "Multi" things (MultiPoint, MultiPolygon, etc).
#
# SimplestMaps also natively supports Telluric, Satellogic's own lib for geo data, in a very similar way (just remember to use "_set" helpers when dealing with GeoVectors that contain shapely's "Multi" things).

# %%
from shapely import Point, LineString, LinearRing, Polygon, MultiPoint, MultiPolygon, MultiLineString

# all shapely coordinates are lon, lat!
shp_point = Point(-65, -35)
shp_multi_point = MultiPoint([[0, 40], [10, 40], [20, 40]])

shp_line = LineString([[0, 10], [15, 10], [15, 5]])
shp_linear_ring = LinearRing([[0, 0], [-5, -5], [-5, 10]])
shp_multi_line = MultiLineString([
    [[50, 30], [60, 40]],
    [[55, 30], [65, 40]],
    [[60, 30], [70, 40]],
])
shp_multi_linear_ring = MultiLineString([
    [[75, 30], [85, 40], [75, 50]],
    [[80, 30], [90, 40], [80, 50]],
    [[85, 30], [95, 40], [85, 50]],
])

shp_polygon = Polygon([[-100, 30], [-100, 40], [-80, 35]])
shp_multi_polygon = MultiPolygon([
    Polygon([(-50, 30), (-50, 40), (-70, 30)]),
    Polygon([(-55, 35), (-55, 45), (-75, 35)]),
])

draw_map(
    dot(shp_point, color="red", popup="a point"),
    dot_set(shp_multi_point, color="black", popup="a multi point"),
    
    line(shp_line, color="green", popup="a line"),
    line(shp_linear_ring, color="orange", popup="a linear ring"),
    line_set(shp_multi_line, color="purple", popup="a multi line"),
    line_set(shp_multi_linear_ring, color="magenta", popup="a multi linear ring"),

    area(shp_polygon, color="cyan", popup="a polygon"),
    area_set(shp_multi_polygon, color="teal", popup="a multi polygon"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea88b974a5f84afc90cb3e05b5ee2352 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea88b974a5f84afc90cb3e05b5ee2352&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea88b974a5f84afc90cb3e05b5ee2352 = L.map(
#                 &quot;map_ea88b974a5f84afc90cb3e05b5ee2352&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4e2a658d592ff6916ecedfb28140e0b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e4e2a658d592ff6916ecedfb28140e0b.addTo(map_ea88b974a5f84afc90cb3e05b5ee2352);
#
#
#             var circle_marker_0f2218e2ede4d4e4f0e1e6e068d38d74 = L.circleMarker(
#                 [-35.0, -65.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_ea88b974a5f84afc90cb3e05b5ee2352);
#
#
#         var popup_d5516056525246229a25495ce0882203 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_576fe130d2745d0df4497d9e36f10249 = $(`&lt;div id=&quot;html_576fe130d2745d0df4497d9e36f10249&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;a point&lt;/div&gt;`)[0];
#                 popup_d5516056525246229a25495ce0882203.setContent(html_576fe130d2745d0df4497d9e36f10249);
#
#
#
#         circle_marker_0f2218e2ede4d4e4f0e1e6e068d38d74.bindPopup(popup_d5516056525246229a25495ce0882203)
#         ;
#
#
#
#
#             var circle_marker_91ffcbb254a9cd1e3055d219083a74d5 = L.circleMarker(
#                 [40.0, 20.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_ea88b974a5f84afc90cb3e05b5ee2352);
#
#
#         var popup_a322859c85ed16af140fec8db8e919fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87f760933db76c9ab98e2981de41e33b = $(`&lt;div id=&quot;html_87f760933db76c9ab98e2981de41e33b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;a multi point&lt;/div&gt;`)[0];
#                 popup_a322859c85ed16af140fec8db8e919fd.setContent(html_87f760933db76c9ab98e2981de41e33b);
#
#
#
#         circle_marker_91ffcbb254a9cd1e3055d219083a74d5.bindPopup(popup_a322859c85ed16af140fec8db8e919fd)
#         ;
#
#
#
#
#             var circle_marker_837f694f1786b32deee767e869aefe08 = L.circleMarker(
#                 [40.0, 10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_ea88b974a5f84afc90cb3e05b5ee2352);
#
#
#         var popup_db54ba2d31a9504178ebb2a580502fb1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_28170045ad860e29cc5f50432b377245 = $(`&lt;div id=&quot;html_28170045ad860e29cc5f50432b377245&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;a multi point&lt;/div&gt;`)[0];
#                 popup_db54ba2d31a9504178ebb2a580502fb1.setContent(html_28170045ad860e29cc5f50432b377245);
#
#
#
#         circle_marker_837f694f1786b32deee767e869aefe08.bindPopup(popup_db54ba2d31a9504178ebb2a580502fb1)
#         ;
#
#
#
#
#             var circle_marker_f43ffdbe1a6805dd9ff534d793f08a0e = L.circleMarker(
#                 [40.0, 0.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&q

# %% [markdown]
# # Custom geometry objects instead of (lat,lon) tuples
#
# 📣 New in v1.2.0! 📣
#
# SimplestMaps supports not only (lat,lon) tuples and shapely objects, but any kind of custom coordinate and geometry containing objects you might have. Some are supported out of the box, and others require just a tiny bit of work to make them compatible.
#
# If you have a class that represents coordinates and has either:
#
# - "lat" and "lon" attributes
# - "latitude" and "longitude" attributes
# - or "latitude_deg" and "longitude_deg" attributes
#
# Then SimplestMaps already supports them out of the box in all the places where you can use tuples.
#
# For instance:

# %%
class House:
    def __init__(self, latitude, longitude):
        self.latitude = latitude
        self.longitude = longitude

house_a = House(-35, -65)
house_b = House(5, -70)
house_c = House(40, -100)

draw_map(
    marker(house_a),
    marker(house_b),
    marker(house_c),
    line([house_a, house_b, house_c]),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cb37b6c07fc1b89f72e2160f3d77620 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cb37b6c07fc1b89f72e2160f3d77620&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cb37b6c07fc1b89f72e2160f3d77620 = L.map(
#                 &quot;map_3cb37b6c07fc1b89f72e2160f3d77620&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1dcbbf43d17ef99e58753ae052059011 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1dcbbf43d17ef99e58753ae052059011.addTo(map_3cb37b6c07fc1b89f72e2160f3d77620);
#
#
#             var marker_9d4c4569d958aeb24f7910f21db81846 = L.marker(
#                 [-35.0, -65.0],
#                 {}
#             ).addTo(map_3cb37b6c07fc1b89f72e2160f3d77620);
#
#
#             var marker_d2c5756070a900dc89cfaac13b4f272e = L.marker(
#                 [5.0, -70.0],
#                 {}
#             ).addTo(map_3cb37b6c07fc1b89f72e2160f3d77620);
#
#
#             var marker_09372497c9a961b25db6618e300a9ae1 = L.marker(
#                 [40.0, -100.0],
#                 {}
#             ).addTo(map_3cb37b6c07fc1b89f72e2160f3d77620);
#
#
#             var poly_line_82f81c857bf964a6ba7c125fccec51d1 = L.polyline(
#                 [[-35.0, -65.0], [5.0, -70.0], [40.0, -100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_3cb37b6c07fc1b89f72e2160f3d77620);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# If your custom geometry objects don't follow those attribute naming conventions or represent more complex types like areas or lines, you can simply extract (lat,lon) tuples and use them as inputs for SimplestMaps. But that's tedious if you are doing lots of maps with your custom types.
#
# If that the case, you can tell SimplestMaps how to convert them to avoid having to manually do it each time you need to draw a map. You only need to write a function that is able to receive an instance of your custom type, and return either a single tuple of (lat,lon) coordinates, or a sequence of tuples of (lat,lon) coordinates.
#
# Like this:
#
# (notice how the converter function used for QuarantineZone can just return a list of House instances, because we also registered a converter for House. SimplestMaps tries to save you work as much as it can :) )

# %%
from simplestmaps import auto_convert

class House:
    def __init__(self, entrance_latitude, entrance_longitude):
        self.entrance_latitude = entrance_latitude
        self.entrance_longitude = entrance_longitude
        
class QuarantineZone:
    def __init__(self, houses):
        self.houses = houses


auto_convert(House, lambda h: (h.entrance_latitude, h.entrance_longitude))
auto_convert(QuarantineZone, lambda q: q.houses)

house_a = House(-35, -65)
house_b = House(5, -70)
house_c = House(40, -100)
quarantine_zone = QuarantineZone([house_a, house_b, house_c])

draw_map(
    marker(house_a),
    marker(house_b),
    marker(house_c),
    area(quarantine_zone, color="red"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31ae322d9f6bdf9238bdd90af2f401db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31ae322d9f6bdf9238bdd90af2f401db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31ae322d9f6bdf9238bdd90af2f401db = L.map(
#                 &quot;map_31ae322d9f6bdf9238bdd90af2f401db&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c75fb45ab876d5669258d239520b0cb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0c75fb45ab876d5669258d239520b0cb.addTo(map_31ae322d9f6bdf9238bdd90af2f401db);
#
#
#             var marker_1f62811d1cc31af1fc687a48a709c2df = L.marker(
#                 [-35.0, -65.0],
#                 {}
#             ).addTo(map_31ae322d9f6bdf9238bdd90af2f401db);
#
#
#             var marker_b5cf9b810dda1dffaa718abd9446b52a = L.marker(
#                 [5.0, -70.0],
#                 {}
#             ).addTo(map_31ae322d9f6bdf9238bdd90af2f401db);
#
#
#             var marker_a74e9a6b542b3c4708ba9fe77f5be68f = L.marker(
#                 [40.0, -100.0],
#                 {}
#             ).addTo(map_31ae322d9f6bdf9238bdd90af2f401db);
#
#
#             var polygon_0951d2c96438150a5d40b0c2c639bd9f = L.polygon(
#                 [[-35.0, -65.0], [5.0, -70.0], [40.0, -100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_31ae322d9f6bdf9238bdd90af2f401db);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
