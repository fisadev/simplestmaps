# %%
from simplestmaps import (
    draw_map, 
    marker,
    dot,
    label,
    html,
    line,
    area,
    geojson,
)

# %% [markdown]
# # Drawing points
#
# **Markers** are the most basic way of showing a point (coordinates are always lat lon):

# %%
draw_map(
    marker(-20, 30),
    marker(40, -100, popup="hello world!"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c1b4765e47c3705b3c7414cb082ff38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c1b4765e47c3705b3c7414cb082ff38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c1b4765e47c3705b3c7414cb082ff38 = L.map(
#                 &quot;map_0c1b4765e47c3705b3c7414cb082ff38&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64b281f1a8a18649be6a4c738ab9dc38 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_64b281f1a8a18649be6a4c738ab9dc38.addTo(map_0c1b4765e47c3705b3c7414cb082ff38);
#
#
#             var marker_3f0aa9586b113aedf0e4f8efc4500c44 = L.marker(
#                 [-20.0, 30.0],
#                 {}
#             ).addTo(map_0c1b4765e47c3705b3c7414cb082ff38);
#
#
#             var marker_6f1f4ae3a0e3bfbf4f6ff633492d7dea = L.marker(
#                 [40.0, -100.0],
#                 {}
#             ).addTo(map_0c1b4765e47c3705b3c7414cb082ff38);
#
#
#         var popup_52510ac2873f2bcb5a935f1301efeec6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_570a75f48abeb7daee2a539c4abacf0d = $(`&lt;div id=&quot;html_570a75f48abeb7daee2a539c4abacf0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hello world!&lt;/div&gt;`)[0];
#                 popup_52510ac2873f2bcb5a935f1301efeec6.setContent(html_570a75f48abeb7daee2a539c4abacf0d);
#
#
#
#         marker_6f1f4ae3a0e3bfbf4f6ff633492d7dea.bindPopup(popup_52510ac2873f2bcb5a935f1301efeec6)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Dots** are a bit more customizable and less intrussive by default (sizes always in pixels):

# %%
draw_map(
    dot(-20, 30),  # by default: small blue dot
    dot(40, -100, popup="hello world!", color="green", radius=10, opacity=0.5, border_color="yellow", border_width=2),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57cb611d59b2b5a6c8a52eff8403c16f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57cb611d59b2b5a6c8a52eff8403c16f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57cb611d59b2b5a6c8a52eff8403c16f = L.map(
#                 &quot;map_57cb611d59b2b5a6c8a52eff8403c16f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b6705165735534de8e34cedc0090731 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9b6705165735534de8e34cedc0090731.addTo(map_57cb611d59b2b5a6c8a52eff8403c16f);
#
#
#             var circle_marker_a6f7ddfc097f1f50324dc01a58775e66 = L.circleMarker(
#                 [-20.0, 30.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_57cb611d59b2b5a6c8a52eff8403c16f);
#
#
#             var circle_marker_479c9f4db710e34068cbf61eb4816cd9 = L.circleMarker(
#                 [40.0, -100.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_57cb611d59b2b5a6c8a52eff8403c16f);
#
#
#         var popup_f965394017d77d49187d17764e3c21ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16a947ad503492dcf32597942df5aed7 = $(`&lt;div id=&quot;html_16a947ad503492dcf32597942df5aed7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hello world!&lt;/div&gt;`)[0];
#                 popup_f965394017d77d49187d17764e3c21ee.setContent(html_16a947ad503492dcf32597942df5aed7);
#
#
#
#         circle_marker_479c9f4db710e34068cbf61eb4816cd9.bindPopup(popup_f965394017d77d49187d17764e3c21ee)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# You can also draw **text labels** or even **custom html** in the locations of your points:

# %%
draw_map(
    label(-20, 30, text="hello world!"),  # by default: small blue text
    label(30, -75, text="Words", font="Verdana", size=30, color="green", opacity=0.9, popup="this is customizable!"),

    html(10, -40, code='<ul style="color:red"><li><strong>apples</strong></li><li>oranges</li></ul>', popup="custom html markers!"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb4e326ad0a9a0eb1e18efa672ce5c10 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb4e326ad0a9a0eb1e18efa672ce5c10&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb4e326ad0a9a0eb1e18efa672ce5c10 = L.map(
#                 &quot;map_bb4e326ad0a9a0eb1e18efa672ce5c10&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80b3be85d159630c3bac2bd570df2833 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_80b3be85d159630c3bac2bd570df2833.addTo(map_bb4e326ad0a9a0eb1e18efa672ce5c10);
#
#
#             var marker_a7806094a7fa79f48c61ed62aa945223 = L.marker(
#                 [-20.0, 30.0],
#                 {}
#             ).addTo(map_bb4e326ad0a9a0eb1e18efa672ce5c10);
#
#
#             var div_icon_691169116b096e3cf556e9726a98d4cd = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                    \u003cdiv style=\&quot;font-family: arial;\n                                font-size: 12px;\n                                color: blue;\n                                opacity: 1\&quot;\u003e\n                        hello world!\n                    \u003c/div\u003e\n                &quot;});
#             marker_a7806094a7fa79f48c61ed62aa945223.setIcon(div_icon_691169116b096e3cf556e9726a98d4cd);
#
#
#             var marker_2b589ee9d0928b7611df4d0e51d9e3eb = L.marker(
#                 [30.0, -75.0],
#                 {}
#             ).addTo(map_bb4e326ad0a9a0eb1e18efa672ce5c10);
#
#
#             var div_icon_2f4dbd8a0102ba9b63c25b3d3c0c7d68 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                    \u003cdiv style=\&quot;font-family: Verdana;\n                                font-size: 30px;\n                                color: green;\n                                opacity: 0.9\&quot;\u003e\n                        Words\n                    \u003c/div\u003e\n                &quot;});
#             marker_2b589ee9d0928b7611df4d0e51d9e3eb.setIcon(div_icon_2f4dbd8a0102ba9b63c25b3d3c0c7d68);
#
#
#         var popup_bcd90a5aa4a283bc0d924d7cfa12f18a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5ed7c459201d7a917fb2c4b1aa2610f = $(`&lt;div id=&quot;html_b5ed7c459201d7a917fb2c4b1aa2610f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;this is customizable!&lt;/div&gt;`)[0];
#                 popup_bcd90a5aa4a283bc0d924d7cfa12f18a.setContent(html_b5ed7c459201d7a917fb2c4b1aa2610f);
#
#
#
#         marker_2b589ee9d0928b7611df4d0e51d9e3eb.bindPopup(popup_bcd90a5aa4a283bc0d924d7cfa12f18a)
#         ;
#
#
#
#
#             var marker_06320c39499799be0d805f0606431406 = L.marker(
#                 [10.0, -40.0],
#                 {}
#             ).addTo(map_bb4e326ad0a9a0eb1e18efa672ce5c10);
#
#
#             var div_icon_694e23d479487e1e420f4d7bd1c7e8c3 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cul style=\&quot;color:red\&quot;\u003e\u003cli\u003e\u003cstrong\u003eapples\u003c/strong\u003e\u003c/li\u003e\u003cli\u003eoranges\u003c/li\u003e\u003c/ul\u003e&quot;});
#             marker_06320c39499799be0d805f0606431406.setIcon(div_icon_694e23d479487e1e420f4d7bd1c7e8c3);
#
#
#         var popup_c87d40804f72503c87953b10e7cd8b69 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab2d1d6626d9b9a34643c34c43ecaa21 = $(`&lt;div id=&quot;html_ab2d1d6626d9b9a34643c34c43ecaa21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;custom html markers!&lt;/div&gt;`)[0];
#                 popup_c87d40804f72503c87953b10e7cd8b69.setContent(html_ab2d1d6626d9b9a34643c34c43ecaa21);
#
#
#
#         marker_06320c39499799be0d805f0606431406.bindPopup(popup_c87d40804f72503c87953b10e7cd8b69)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Lines and Areas
#
# Lines and areas are super easy, they're just sequences of point coordinates and also quite customizable:

# %%
draw_map(
    line([(-35, -65), (5, -70), (40, -100)]),  # by default: thin line
    line([(20, 0), (20, 30), (-20, 30)], color="green", width=10, opacity=0.5, popup="hi!"),

    area([(25, -80), (32, -64), (18, -66)]),  # by default: blue area
    area([(30, 0), (30, 25), (50, 15), (50, 0)], color="green", opacity=0.2, border_color="red", border_width=2, popup="hi!"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2df88319c3ccc5533bdc1337a8e90e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2df88319c3ccc5533bdc1337a8e90e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2df88319c3ccc5533bdc1337a8e90e8 = L.map(
#                 &quot;map_a2df88319c3ccc5533bdc1337a8e90e8&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f18521e35c858d7cd02b8366d4da0f7f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f18521e35c858d7cd02b8366d4da0f7f.addTo(map_a2df88319c3ccc5533bdc1337a8e90e8);
#
#
#             var poly_line_170b5feb5078fea4e32159652f0c623c = L.polyline(
#                 [[-35.0, -65.0], [5.0, -70.0], [40.0, -100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_a2df88319c3ccc5533bdc1337a8e90e8);
#
#
#             var poly_line_968e9e22dd4b7b8988e06815e5015ed0 = L.polyline(
#                 [[20.0, 0.0], [20.0, 30.0], [-20.0, 30.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_a2df88319c3ccc5533bdc1337a8e90e8);
#
#
#         var popup_10435df7b5114a5fc6ece30006569d66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9104183a79cb8a369e0b76a52ce26aa5 = $(`&lt;div id=&quot;html_9104183a79cb8a369e0b76a52ce26aa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hi!&lt;/div&gt;`)[0];
#                 popup_10435df7b5114a5fc6ece30006569d66.setContent(html_9104183a79cb8a369e0b76a52ce26aa5);
#
#
#
#         poly_line_968e9e22dd4b7b8988e06815e5015ed0.bindPopup(popup_10435df7b5114a5fc6ece30006569d66)
#         ;
#
#
#
#
#             var polygon_76043d33366c5365e937893debd2ba7c = L.polygon(
#                 [[25.0, -80.0], [32.0, -64.0], [18.0, -66.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_a2df88319c3ccc5533bdc1337a8e90e8);
#
#
#             var polygon_69a86dfdc35abf004c61bfc7140bc846 = L.polygon(
#                 [[30.0, 0.0], [30.0, 25.0], [50.0, 15.0], [50.0, 0.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_a2df88319c3ccc5533bdc1337a8e90e8);
#
#
#         var popup_b52f097635507b6396e8962c2a3a73c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f05040b1138d63e989bbc7ab8e7b949e = $(`&lt;div id=&quot;html_f05040b1138d63e989bbc7ab8e7b949e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hi!&lt;/div&gt;`)[0];
#                 popup_b52f097635507b6396e8962c2a3a73c1.setContent(html_f05040b1138d63e989bbc7ab8e7b949e);
#
#
#
#         polygon_69a86dfdc35abf004c61bfc7140bc846.bindPopup(popup_b52f097635507b6396e8962c2a3a73c1)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Geojson files!
#
# It's super simple to just plot the contents of geojson files.
#
# To customize the elements from the geojson, you can use the same functions used to create normal elements:
#
# - points can be configured to be shown as markers, dots, labels, or htmls
# - lines can be customized with the lines function
# - and areas can be customized with the area function

# %%
draw_map(
    geojson("./readme_example.geojson"),

    geojson("./demo.geojson", 
            points_as=label(text="X", color="green"),
            lines_as=line(color="cyan", width=20, opacity=0.3),
            areas_as=area(color="yellow", border_color="black")),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2a03a08c9f1b0b16a2540dc3a2b182d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2a03a08c9f1b0b16a2540dc3a2b182d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2a03a08c9f1b0b16a2540dc3a2b182d = L.map(
#                 &quot;map_f2a03a08c9f1b0b16a2540dc3a2b182d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c00c5a5f784ad264293c63b485655aad = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c00c5a5f784ad264293c63b485655aad.addTo(map_f2a03a08c9f1b0b16a2540dc3a2b182d);
#
#
#             var marker_f44d965379c8e0cfe45f101cc41f1ad4 = L.marker(
#                 [-31.266876721234745, -61.49754063958642],
#                 {}
#             ).addTo(map_f2a03a08c9f1b0b16a2540dc3a2b182d);
#
#
#             var marker_0e2a2fe6bcc0b0246b6c0aefb0a252da = L.marker(
#                 [-31.28080113214235, -61.5057564776007],
#                 {}
#             ).addTo(map_f2a03a08c9f1b0b16a2540dc3a2b182d);
#
#
#             var marker_07a9c254aaed7721c75ca7dac7f79835 = L.marker(
#                 [-31.274935068612756, -61.49530790700085],
#                 {}
#             ).addTo(map_f2a03a08c9f1b0b16a2540dc3a2b182d);
#
#
#             var marker_a3c26c396de54da88c52ab82f9d84411 = L.marker(
#                 [-31.252650216241804, -61.49174942173205],
#                 {}
#             ).addTo(map_f2a03a08c9f1b0b16a2540dc3a2b182d);
#
#
#             var polygon_dee0494e5d1ea327bdb19d03543f59ac = L.polygon(
#                 [[-31.27388756140052, -61.510273604158314], [-31.287343249057386, -61.51410096629422], [-31.28979628904363, -61.500270271302114], [-31.276043574213098, -61.497138793191084], [-31.27388756140052, -61.510273604158314]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_f2a03a08c9f1b0b16a2540dc3a2b182d);
#
#
#             var poly_line_d2ee48b37dcd01719eccf246d84fcd6c = L.polyline(
#                 [[-31.29126457848656, -61.523441142102016], [-31.26752139349587, -61.47841963805594], [-31.25286836171494, -61.491620691758996], [-31.241750751306256, -61.4445303658637]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_f2a03a08c9f1b0b16a2540dc3a2b182d);
#
#
#             var marker_bba03cd5af6d5c28cd1013e6855a8612 = L.marker(
#                 [38.09287655309984, -100.58094196533119],
#                 {}
#             ).addTo(map_f2a03a08c9f1b0b16a2540dc3a2b182d);
#
#
#             var div_icon_4a7e868001e45a1a53cae0d1ef1a1ef6 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                    \u003cdiv style=\&quot;font-family: arial;\n                                font-size: 12px;\n                                color: green;\n                                opacity: 1\&quot;\u003e\n                        X\n                    \u003c/div\u003e\n                &quot;});
#             marker_bba03cd5af6d5c28cd1013e6855a8612.setIcon(div_icon_4a7e868001e45a1a53cae0d1ef1a1ef6);
#
#
#             var polygon_c353afa28955dd846b09140123eafe50 = L.polygon(
#                 [[27.835518539468566, -103.84614574318596], [18.955163888868427, -103.84614574318596], [18.955163888868427, -82.43532147866615], [27.835518539468566, -82.43532147866615], [27.835518539468566, -103.84614574318596]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_f2a03a08c9f1b0b16a2540dc3a2b182d);

# %% [markdown]
# # Sets of points, areas or lines
#
# If you have a set of points, lines, areas or geojsons for which you want to use the same style without having to call the helper functions for each element (like in a list comprehension), you can instead use these other helpers. They work just like the single-element versions, except they expect a list of elements as the first argument:

# %%
from simplestmaps import (
    marker_set,
    dot_set,
    label_set,
    html_set,
    line_set,
    area_set,
    geojson_set,
)

draw_map(
    dot_set([(0, -80), (0, 0), (0, 80)], color="green", radius=10),
    line_set([
        [(10, -100), (10, 100)],
        [(-10, -100), (-10, 100)],
    ], color="yellow"),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa726fc4c9fcd383dbd5b095a3f6f9af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa726fc4c9fcd383dbd5b095a3f6f9af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa726fc4c9fcd383dbd5b095a3f6f9af = L.map(
#                 &quot;map_fa726fc4c9fcd383dbd5b095a3f6f9af&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a036407fe246655f58046d8d37e0fa7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7a036407fe246655f58046d8d37e0fa7.addTo(map_fa726fc4c9fcd383dbd5b095a3f6f9af);
#
#
#             var circle_marker_b262a2040b45e23f3612cda7b37cae51 = L.circleMarker(
#                 [0.0, 80.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_fa726fc4c9fcd383dbd5b095a3f6f9af);
#
#
#             var circle_marker_310aa17113e70da6157abf0a4c526b88 = L.circleMarker(
#                 [0.0, 0.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_fa726fc4c9fcd383dbd5b095a3f6f9af);
#
#
#             var circle_marker_16b46a24894c8f458012d67d685ad100 = L.circleMarker(
#                 [0.0, -80.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_fa726fc4c9fcd383dbd5b095a3f6f9af);
#
#
#             var poly_line_3bacec379675367841667a27507fbdec = L.polyline(
#                 [[-10.0, -100.0], [-10.0, 100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_fa726fc4c9fcd383dbd5b095a3f6f9af);
#
#
#             var poly_line_b935fd2b19429300517d2d130fd516f9 = L.polyline(
#                 [[10.0, -100.0], [10.0, 100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_fa726fc4c9fcd383dbd5b095a3f6f9af);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Custom geometry objects instead of (lat,lon) tuples
#
# SimplestMaps supports not only (lat,lon) tuples, but any kind of custom coordinate and geometry containing objects.
#
# If you have a class that represents coordinates and has either:
#
# - "lat" and "lon" attributes
# - "latitude" and "longitude" attributes
# - or "latitude_deg" and "longitude_deg" attributes
#
# Then SimplestMaps already supports them out of the box in al the places where you can use tuples.
#
# For instance:

# %%
class MyCustomPoint:
    def __init__(self, latitude, longitude):
        self.latitude = latitude
        self.longitude = longitude


point_a = MyCustomPoint(-35, -65)
point_b = MyCustomPoint(5, -70)
point_c = MyCustomPoint(40, -100)

draw_map(
    marker(point_a),
    marker(point_b),
    marker(point_c),
    line([point_a, point_b, point_c]),
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0361d53c25a380a06ff0d11f53ff82ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0361d53c25a380a06ff0d11f53ff82ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0361d53c25a380a06ff0d11f53ff82ea = L.map(
#                 &quot;map_0361d53c25a380a06ff0d11f53ff82ea&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb991933c6a790b641e3563cec29afbf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bb991933c6a790b641e3563cec29afbf.addTo(map_0361d53c25a380a06ff0d11f53ff82ea);
#
#
#             var marker_516d46c53e03a2a8e2cb835f6accf7f1 = L.marker(
#                 [-35.0, -65.0],
#                 {}
#             ).addTo(map_0361d53c25a380a06ff0d11f53ff82ea);
#
#
#             var marker_b9a1dc9d7f3ac275a78b47ade8febc43 = L.marker(
#                 [5.0, -70.0],
#                 {}
#             ).addTo(map_0361d53c25a380a06ff0d11f53ff82ea);
#
#
#             var marker_c1dfeb4fd00ba4a2655ce82df33aac75 = L.marker(
#                 [40.0, -100.0],
#                 {}
#             ).addTo(map_0361d53c25a380a06ff0d11f53ff82ea);
#
#
#             var poly_line_511c9b5eb1bec2d7ad5a12fe2e85d5df = L.polyline(
#                 [[-35.0, -65.0], [5.0, -70.0], [40.0, -100.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_0361d53c25a380a06ff0d11f53ff82ea);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# If your custom geometry objects don't follow those attribute naming conventions or represent more complex types like areas or lines, I'm still working in a very simple way of adding that to SimplestMaps.
#
# It will look something like this:
#
# ```python
# from simplestmaps import auto_convert
#
# auto_convert(MyCustomType, a_function_that_receives_custom_type_and_returns_simplestmaps_type)
# ```
#
# **This is a work in progress, not yet released!!**

# %% [markdown]
# # Integration with Shapely
#
# I'm also working to support shapely polygons and other types of objects! Stay tunned, it's one of my biggest priorities :)
